# %% [markdown]
# # Bài 1

# %%
a,b=map(float,input().split())
if a>0 and b>0:
    s=a*b
    p=(a+b)*2
    print(s,p)
else:
    print('khong hop le')
# Out:
# 12.0 14.0

# %% [markdown]
# ## Bài 2

# %%
r=float(input())
if r>0:
    s=3.14*(r**2)
    p=2*3.14*r
    print(s,p)
else:
    print('khong hop le')
# Out:
# 50.24 25.12
