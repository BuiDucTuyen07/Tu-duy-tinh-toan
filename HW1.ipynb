# %% [markdown]
# ## Bài 1

# %%
n=int(input())
print(n*2)
# Out:
# 4

# %% [markdown]
# ## Bài 2

# %%
a, b, r=map(float, input().split())
s=a*b-3.14*r**2
print(s)
# Out:
# 8.86

# %% [markdown]
# ### bài 3

# %%
c = input()
ma_so = ord(c)
ma_hoa= ma_so - 32
ki_tu_hoa=chr(ma_hoa)
print(ki_tu_hoa)

# %%
c=input()
if 'A'<=c<='Z' or 'a'<=c<='z':
    print(c,'là kí tự alaphabet')
else:
    print(c,'không phải là kí tự alphabet')
# Out:
# a là kí tự alaphabet

# %%
c=input()
d=ord(c)
e=d-1
if c=='A':
    print('z')
else:
    print(chr(e+32))
# Out:
# 

# %%
a,b,c=map(float,input().split())
if a >0 and b>0 and c>0 and a+b>c and a+c>b and b+c>a :
    A=(a+b+c)/2
    B=A*(A-a)*(A-b)*(A-c)
    C=B**(1/2)
    print('%.1f'%C)
else:
    print('khong phai 3 canh tam giac')
# Out:
# 6.0

# %%
s=input()
print(s[4],s[8])
# Out:
# e i
